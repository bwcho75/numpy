# %%
from matplotlib import pyplot as plt

labels = 'java','python','ruby','go'
value=[15,30,45,10]

plt.pie(value,labels=labels)
plt.show()

# %%
from matplotlib import pyplot as plt

labels = 'java','python','ruby','go'
value=[15,30,45,10]

plt.pie(value,labels=labels,autopct='%0.5f') #autopct %0.Nf
plt.axis('equal')
plt.show()
