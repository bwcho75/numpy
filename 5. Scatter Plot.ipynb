# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(50)
y = np.random.rand(50)
colors = np.random.rand(50)
area =  (20*np.random.rand(50))**2*np.pi #0 to 15 point radi

plt.scatter(x, y, s=area,c=colors,alpha=0.2)
plt.show()
